# %%
import os
os.listdir()
# Out:
# ['FirstProject.ipynb',
#  '.ipynb_checkpoints',
#  'supermarkets-semi-colons.txt',
#  'Testings.ipynb',
#  'supermarkets.xlsx',
#  'supermarkets-commas.txt',
#  'supermarkets.json',
#  'supermarkets.csv']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
import pandas

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")

# %%
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8 = pandas.read_csv("supermarkets-semi-colons.txt", delimiter=";", header=None)
df8
# Out:
#     0                1              2                 3        4  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#               5          6
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df8.columns=["id","adress","city","state","country","name","employees"]
df8
# Out:
#    id           adress           city             state  country  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#            name  employees
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df8.set_index=["IDDD"]
df8
# Out:
#    id           adress           city             state  country  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#            name  employees
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df9 = df8.set_index=["IDDD"]
df9
# Out:
# ['IDDD']

# %%
df8
# Out:
#    id           adress           city             state  country  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#            name  employees
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
import geopy

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
nom.geocode("17 Río Balsas Tlaltenango Zacatecas CP 99700")
# Out:
# Location(Calle Río Balsas 17, Fracc Brisas, Tlaltenango de Sánchez Román, Zacatecas, 99700, (21.788099995715584, -103.29881998863948, 0.0))

# %%
df8
# Out:
#    id           adress           city             state  country  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#            name  employees
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5["Address"] = df5["Address"] +","+df5["City"] + "," +df5["State"]

# %%
df5
# Out:
#    ID                                     Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114  San Francisco
#
#               State Country          Name  Employees
# 0          CA 94114     USA       Madeira          8
# 1          CA 94119     USA   Bready Shop         15
# 2  California 94114     USA   Super River         25
# 3          CA 94114     USA    Ben's Shop         10
# 4        California     USA       Sanchez         12
# 5          CA 94114     USA    Richvalley         20

# %%
df5["Cordinates"] = df["Address"].apply(nom.geocode)
df5
# Out:
#    ID                                     Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114  San Francisco
#
#               State Country          Name  Employees  \
# 0          CA 94114     USA       Madeira          8
# 1          CA 94119     USA   Bready Shop         15
# 2  California 94114     USA   Super River         25
# 3          CA 94114     USA    Ben's Shop         10
# 4        California     USA       Sanchez         12
# 5          CA 94114     USA    Richvalley         20
#
#                                           Cordinates
# 0  (3666 21st St, San Francisco, California, 9411...
# ...

# %%
df5["Cordinates"][0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756648011392286, -122.42937496976432, 0.0))

# %%
df5["Latitude"] = df5["Cordinates"].apply(lambda x: x.latitude if x!= None else None)
df5["Latitud"] = df5["Cordinates"].apply(lambda x: x.latitude if x!= None else None)
df5
# Out:
#    ID                                     Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114  San Francisco
#
#               State Country          Name  Employees  \
# 0          CA 94114     USA       Madeira          8
# 1          CA 94119     USA   Bready Shop         15
# 2  California 94114     USA   Super River         25
# 3          CA 94114     USA    Ben's Shop         10
# 4        California     USA       Sanchez         12
# 5          CA 94114     USA    Richvalley         20
#
#                                           Cordinates   Latitude
# 0  (3666 21st St, San Francisco, California, 9411...  37.756648
# ...
